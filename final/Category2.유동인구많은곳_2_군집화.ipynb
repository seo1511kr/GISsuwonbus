# %% [markdown]
# # Category2.유동인구많은곳_2_군집화

# %% [markdown]
# ## (2) 군집화

# %% [markdown]
# <군집화 에 사용된 라이브러리>

# %%
import pandas as pd
import warnings 
import geopandas as gpd
import numpy as np
from shapely.geometry import Polygon, LineString, Point
warnings.filterwarnings(action='ignore')

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist, pdist
from sklearn.preprocessing import StandardScaler
# Out:
# /opt/app-root/lib/python3.6/site-packages/geopandas/_compat.py:91: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# 전처리 파일에서 저장한 데이터 불러오기

# %%
data = pd.read_csv('data/category2_after_preprocessing.csv')

# %%
#변수들간의 상관관계
data[['인구_계','전체_추정교통량','버스_추정교통량','버스승하차','평일유동인구','주말유동인구','혼잡빈도강도','혼잡시간강도']].corr()
# Out:
#               인구_계  전체_추정교통량  버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
# 인구_계      1.000000 -0.109126 -0.067993 -0.202295  0.013615  0.010698
# 전체_추정교통량 -0.109126  1.000000  0.943637  0.147830  0.234678  0.234867
# 버스_추정교통량 -0.067993  0.943637  1.000000  0.078984  0.210287  0.217347
# 버스승하차    -0.202295  0.147830  0.078984  1.000000  0.269604  0.256832
# 평일유동인구    0.013615  0.234678  0.210287  0.269604  1.000000  0.952471
# 주말유동인구    0.010698  0.234867  0.217347  0.256832  0.952471  1.000000
# 혼잡빈도강도   -0.015201 -0.092434 -0.069214  0.086502 -0.064602 -0.073002
# 혼잡시간강도    0.037431 -0.188906 -0.163446 -0.002484 -0.118700 -0.126586
#
#             혼잡빈도강도    혼잡시간강도
# 인구_계     -0.015201  0.037431
# 전체_추정교통량 -0.092434 -0.188906
# 버스_추정교통량 -0.069214 -0.163446
# 버스승하차     0.086502 -0.002484
# 평일유동인구   -0.064602 -0.118700
# 주말유동인구   -0.073002 -0.126586
# 혼잡빈도강도    1.000000  0.923802
# 혼잡시간강도    0.923802  1.000000

# %% [markdown]
# ## (2) 1. 결측값 대체

# %%
data.isnull().sum()
# Out:
# 정류장ID         0
# 정류장명          0
# 동             0
# lon           0
# lat           0
# 인구_계         27
# 전체_추정교통량      0
# 승용차_추정교통량     0
# 버스_추정교통량      0
# 화물차_추정교통량     0
# 전체 승차 건수      9
# 전체 하차 건수      9
# 버스승하차         9
# 평일유동인구        0
# 주말유동인구        0
# 혼잡빈도강도       28
# 혼잡시간강도       28
# dtype: int64

# %% [markdown]
# ### -인구_계 결측값 대체
# ##### 태장동 -> 망포1.2동으로 이름 교체했기때문에, 동 이름 변경 후 망포1.2동의 인구로 NaN 대체

# %%
for i in range(len(data)):
    if data['동'][i]=='태장동':
        data['동'][i] ='망포1.2동'

# %%
data['인구_계'] =data.apply(lambda x: 60097 if x.동=='망포1.2동' else x.인구_계,axis=1)
data['인구_계'] =data.apply(lambda x: 11263 if x.동=='지동' else x.인구_계,axis=1)
data['인구_계'].isnull().sum()
# Out:
# 0

# %%
data.head()
# Out:
#        정류장ID     정류장명     동         lon        lat     인구_계   전체_추정교통량  \
# 0  201000313     권선구청   서둔동  126.970983  37.256983  38211.0   446123.0
# 1  201000345  남수원초등학교  세류2동  127.016000  37.251091  23728.0   749320.0
# 2  201000379   신미주아파트   금곡동  126.953845  37.268806  45794.0   131512.0
# 3  201000055   농수산물시장  권선1동  127.029815  37.256755  24895.0   495990.0
# 4  201000268    곡반중학교   곡선동  127.034254  37.246081  27497.0  1031383.0
#
#    승용차_추정교통량  버스_추정교통량  화물차_추정교통량  전체 승차 건수  전체 하차 건수     버스승하차    평일유동인구  \
# 0   355781.0    5243.0    85100.0   15434.0     623.0   16057.0  12430.86
# 1   612913.0    9680.0   126724.0    5517.0    3474.0    8991.0  14741.39
# 2   106414.0     592.0    24507.0    3018.0   26449.0   29467.0  11751.85
# 3   420745.0    4284.0    70964.0   42604.0   73082.0  115686.0  11958.05
# 4   849483.0   15600.0   166306.0  142617.0   84751.0  227368.0  33588.21
#
#     주말유동인구      혼잡빈도강도      혼잡시간강도
# 0  2878.70  228.235556  312.944444
# 1  4190.02  106.830000  157.968750
# 2  5055.53  327.900000  377.447500
# 3  3870.45  241.273333  342.006667
# 4  9487.21   83.941250  149.207500

# %% [markdown]
# ### 승하차 관련 데이터 결측값 대체
# ####  방법: 중앙값으로 대체/ 유동인구와 가장 상관관계 높기때문에 유동인구에 비례해서 대체

# %%
len(data)
# Out:
# 928

# %%
data.isnull().sum()
# Out:
# 정류장ID         0
# 정류장명          0
# 동             0
# lon           0
# lat           0
# 인구_계          0
# 전체_추정교통량      0
# 승용차_추정교통량     0
# 버스_추정교통량      0
# 화물차_추정교통량     0
# 전체 승차 건수      9
# 전체 하차 건수      9
# 버스승하차         9
# 평일유동인구        0
# 주말유동인구        0
# 혼잡빈도강도       28
# 혼잡시간강도       28
# dtype: int64

# %%
data[data['버스승하차'].isnull()]
# Out:
#          정류장ID            정류장명     동         lon        lat     인구_계  \
# 17   200000293      동원고교.해우재입구   파장동  126.981611  37.315830  23573.0
# 671  201000417         칠보마을7단지   금곡동  126.943095  37.269382  45794.0
# 708  201000418         칠보마을5단지   금곡동  126.941733  37.272319  45794.0
# 714  201000597  수원역환승센터(11승강장)   서둔동  126.998833  37.265962  38211.0
# 730  201000419         칠보마을5단지   금곡동  126.941514  37.272270  45794.0
# 817  200000318           밤꽃사거리   율천동  126.972999  37.305283  43017.0
# 818  200000317           밤꽃사거리   율천동  126.972617  37.305239  43017.0
# 866  202000157         지동새마을금고    지동  127.020107  37.277626  11263.0
# 912  202000258          율천고등학교  화서2동  126.978501  37.288431  26776.0
#
#      전체_추정교통량  승용차_추정교통량  버스_추정교통량  화물차_추정교통량  전체 승차 건수  전체 하차 건수  버스승하차  \
# 17   300588.0   246388.0    2668.0    51528.0       NaN       NaN    NaN
# 671  130310.0   105633.0     826.0    23851.0       NaN       NaN    NaN
# 708  166191.0   132258.0    1186.0    32739.0       NaN       NaN    NaN
# 714  489382.0   395385.0    4355.0    89647.0       NaN       NaN    NaN
# 730  166191.0   132258.0    1186.0    32739.0       NaN       NaN    NaN
# 817  448137.0   358976.0    4461.0    84693.0       NaN       NaN    NaN
# 818  450317.0   360535.0    4469.0    85308.0       NaN       NaN    NaN
# 866  221120.0   190141.0    1666.0    29316.0       NaN       NaN    NaN
# 912  265610.0   195404.0    2292.0    67910.0       NaN       NaN    NaN
#
#         평일유동인구    주말유동인구      혼잡빈도강도      혼잡시간강도
# 17     3390.26   1049.26   60.362941  107.659412
# 671     628.88    289.44  284.433333  345.675556
# 708    7277.63   3190.31  310.005000  346.537500
# 714  240206.76  90920.67   64.648636  102.545455
# 730    7277.63   3190.31  305.964000  343.357333
# 817   13548.64   4932.69  121.679565  172.671304
# 818   17316.59   7377.57  118.826667  170.007917
# 866    3998.34   1568.20  225.395000  243.385000
# 912    9421.98   3918.64  139.857778  230.644444

# %%
from math import isnan
for i in range(len(data)):
    if isnan(data['버스승하차'][i]):
        data['버스승하차'][i] = data[(data['평일유동인구']<=(data['평일유동인구'][i]+1000))&(data['평일유동인구']>=(data['평일유동인구'][i]-1000))]['버스승하차'].median()

# %%
data.head()
# Out:
#        정류장ID     정류장명     동         lon        lat     인구_계   전체_추정교통량  \
# 0  201000313     권선구청   서둔동  126.970983  37.256983  38211.0   446123.0
# 1  201000345  남수원초등학교  세류2동  127.016000  37.251091  23728.0   749320.0
# 2  201000379   신미주아파트   금곡동  126.953845  37.268806  45794.0   131512.0
# 3  201000055   농수산물시장  권선1동  127.029815  37.256755  24895.0   495990.0
# 4  201000268    곡반중학교   곡선동  127.034254  37.246081  27497.0  1031383.0
#
#    승용차_추정교통량  버스_추정교통량  화물차_추정교통량  전체 승차 건수  전체 하차 건수     버스승하차    평일유동인구  \
# 0   355781.0    5243.0    85100.0   15434.0     623.0   16057.0  12430.86
# 1   612913.0    9680.0   126724.0    5517.0    3474.0    8991.0  14741.39
# 2   106414.0     592.0    24507.0    3018.0   26449.0   29467.0  11751.85
# 3   420745.0    4284.0    70964.0   42604.0   73082.0  115686.0  11958.05
# 4   849483.0   15600.0   166306.0  142617.0   84751.0  227368.0  33588.21
#
#     주말유동인구      혼잡빈도강도      혼잡시간강도
# 0  2878.70  228.235556  312.944444
# 1  4190.02  106.830000  157.968750
# 2  5055.53  327.900000  377.447500
# 3  3870.45  241.273333  342.006667
# 4  9487.21   83.941250  149.207500

# %%
data['버스승하차'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 혼잡빈도강도, 혼잡시간강도 결측값 대체

# %%
data[data['혼잡빈도강도'].isnull()]
# Out:
#          정류장ID                정류장명     동         lon        lat     인구_계  \
# 36   201000112  세류3동주민센터.버드내노인복지회관  세류3동  127.012842  37.260231  19312.0
# 37   201000260             국립축산과학원    평동  126.966306  37.236135  41041.0
# 48   201000074       전원아파트.한라녹턴아파트  세류2동  127.015397  37.254431  23728.0
# 87   200000167      연무시장입구.연무동문화센터   연무동  127.026101  37.293217  16300.0
# 104  200000117        북수원시장.효자문사거리  정자1동  126.990938  37.306325  29779.0
# 129  202000075      경기아트센터.매탄위브하늘채   인계동  127.038914  37.262153  39288.0
# 132  201000259                 서둔동   서둔동  126.986174  37.270729  38211.0
# 647   20441.0    17384.0      67.0     2992.0    7790.0     762.0    8552.0
# 698   35515.0    30269.0     288.0     4959.0   87623.0   34224.0  121847.0
# 727  311763.0   270864.0    2403.0    38492.0    7514.0   14751.0   22265.0
# 750   64176.0    55288.0     194.0     8694.0   11600.0     768.0   12368.0
# 752  169082.0   145624.0    1297.0    22160.0    3513.0   12839.0   16352.0
# 782  659241.0   533467.0    9766.0   116009.0   36614.0   39600.0   76214.0
# 793   68355.0    58708.0     210.0     9436.0     587.0   10686.0   11273.0
# 883       0.0        0.0       0.0        0.0   23713.0   23853.0   47566.0
# 895       0.0        0.0       0.0        0.0    5028.0    8412.0   13440.0
# 896       0.0        0.0       0.0        0.0    7990.0    2895.0   10885.0
#
#        평일유동인구    주말유동인구  혼잡빈도강도  혼잡시간강도
# 36   11758.65   4594.28     NaN     NaN
# 37    4469.31   1321.22     NaN     NaN
# 48   38990.08  16411.81     NaN     NaN
# 87    5246.70   1909.85     NaN     NaN
# 104  11914.19   3868.61     NaN     NaN
# 129  16708.99   5557.05     NaN     NaN
# 132   5685.48   1701.11     NaN     NaN
# 136   3837.13   1117.87     NaN     NaN
# 202   2160.51    946.52     NaN     NaN
# 268   7922.76   4550.08     NaN     NaN
# 353  20369.03   7105.19     NaN     NaN
# 374  38990.08  16411.81     NaN     NaN
# 399  17266.99   6671.52     NaN     NaN
# 422  28855.58   9931.09     NaN     NaN
# 441  33691.39  10845.05     NaN     NaN
# 448  16133.70   5621.39     NaN     NaN
# 481   6299.91   1958.44     NaN     NaN
# 559  16795.96   5543.01     NaN     NaN
# 647   1350.22    962.56     NaN     NaN
# 698  17633.35   6526.52     NaN     NaN
# 727   6248.22   1827.34     NaN     NaN
# 750   3543.08   1270.77     NaN     NaN
# 752    857.57    269.65     NaN     NaN
# 782  80963.49  29282.57     NaN     NaN
# 793   1893.59    676.39     NaN     NaN
# 883   7093.08   3441.97     NaN     NaN
# 895   2569.14    773.33     NaN     NaN
# 896   2569.14    773.33     NaN     NaN

# %%
from math import isnan
for i in range(len(data)):
    if isnan(data['혼잡빈도강도'][i]):
        data['혼잡빈도강도'][i] = data[data['동']==data['동'][i]]['혼잡빈도강도'].median()
        data['혼잡시간강도'][i] = data[data['동']==data['동'][i]]['혼잡시간강도'].median()

# %%
data.isnull().sum()
# Out:
# 정류장ID        0
# 정류장명         0
# 동            0
# lon          0
# lat          0
# 인구_계         0
# 전체_추정교통량     0
# 승용차_추정교통량    0
# 버스_추정교통량     0
# 화물차_추정교통량    0
# 전체 승차 건수     9
# 전체 하차 건수     9
# 버스승하차        0
# 평일유동인구       0
# 주말유동인구       0
# 혼잡빈도강도       0
# 혼잡시간강도       0
# dtype: int64

# %% [markdown]
# # 2. K-means 모델링

# %% [markdown]
# data파일을 복사하기

# %%
df = data.copy()

# %% [markdown]
# 정류소 정보 데이터 남기기

# %%
busstop_info = df[['정류장ID','정류장명','동','lat','lon']]

# %% [markdown]
# - 모델링에 사용할 feature만 골라서 데이터프레임 만들기

# %%
total=df.loc[:,['전체_추정교통량','버스_추정교통량','버스승하차','평일유동인구','주말유동인구','혼잡빈도강도']]
total
labels= np.array(df['정류장ID'])

# %%
total
# Out:
#       전체_추정교통량  버스_추정교통량     버스승하차    평일유동인구    주말유동인구      혼잡빈도강도
# 0     446123.0    5243.0   16057.0  12430.86   2878.70  228.235556
# 1     749320.0    9680.0    8991.0  14741.39   4190.02  106.830000
# 2     131512.0     592.0   29467.0  11751.85   5055.53  327.900000
# 3     495990.0    4284.0  115686.0  11958.05   3870.45  241.273333
# 4    1031383.0   15600.0  227368.0  33588.21   9487.21   83.941250
# ..         ...       ...       ...       ...       ...         ...
# 923    61673.0     321.0   67433.0   6215.05   2217.34  283.400000
# 924   130962.0     658.0   55640.0   7356.28   2390.84  203.522000
# 925   172323.0    1302.0  141976.0  18654.19   7775.04  181.568333
# 926   558920.0    5998.0   15298.0  63708.36  26037.05  278.155385
# 927   753016.0    8336.0   27091.0  13770.16   5373.42   91.691000
#
# [928 rows x 6 columns]

# %% [markdown]
# ## 2-1 데이터 표준화

# %%
sd = StandardScaler()
total_sd=pd.DataFrame(sd.fit_transform(total))
total_sd.index = labels

# %%
total_sd.head()
# Out:
#                   0         1         2         3         4         5
# 201000313  0.245680  0.337317 -0.499007 -0.400686 -0.500339  0.430307
# 201000345  1.498794  1.637912 -0.517143 -0.326289 -0.389332 -1.040064
# 201000379 -1.054609 -1.026007 -0.464587 -0.422549 -0.316065  1.637366
# 201000055  0.451780  0.056210 -0.243285 -0.415909 -0.416385  0.588211
# 201000268  2.664561  3.373212  0.043373  0.280556  0.059086 -1.317275

# %% [markdown]
# ## 2-2 가장 적합한 k 찾기

# %%
dist =[]
for i in range(1,20):
    k = KMeans(n_clusters=i,
          init='k-means++',
           n_init=10,
           max_iter=300,
           random_state=0)
    k.fit(total_sd)
    dist.append(k.inertia_)

plt.plot(range(1,20),dist, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2-3 k-means train

# %%
np.random.seed(1234)

# %%
total_sd_arr = total_sd.values

#k값을 5로 설정 후 k-means에 적용시키기
kmeans = KMeans(n_clusters =5,random_state=2021).fit(total_sd_arr)
kmeans.cluster_centers_
# Out:
# array([[-0.66841333, -0.64184789, -0.1147223 , -0.26924527, -0.25131496,
#          0.68935478],
#        [ 1.29655607,  1.34203946,  0.09966244,  0.14894284,  0.13039991,
#          0.17426163],
#        [ 0.35348495,  0.3853127 ,  0.15999784,  3.42052849,  3.3456416 ,
#         -0.49150956],
#        [-0.17975241, -0.23687447, -0.13229527, -0.28891686, -0.28454363,
#         -0.84981466],
#        [ 0.96632536,  0.54768296,  9.08347885,  1.86552665,  1.74982564,
#          0.74264729]])

# %%
total_sd['cluster'] = kmeans.labels_
total_sd
# Out:
#                   0         1         2         3         4         5  cluster
# 201000313  0.245680  0.337317 -0.499007 -0.400686 -0.500339  0.430307        0
# 201000345  1.498794  1.637912 -0.517143 -0.326289 -0.389332 -1.040064        1
# 201000379 -1.054609 -1.026007 -0.464587 -0.422549 -0.316065  1.637366        0
# 201000055  0.451780  0.056210 -0.243285 -0.415909 -0.416385  0.588211        0
# 201000268  2.664561  3.373212  0.043373  0.280556  0.059086 -1.317275        1
# ...             ...       ...       ...       ...       ...       ...      ...
# 202000249 -1.343254 -1.105444 -0.367138 -0.600827 -0.556324  1.098416        0
# 202000241 -1.056882 -1.006661 -0.397408 -0.564081 -0.541637  0.130995        0
# 202000246 -0.885937 -0.817888 -0.175806 -0.200302 -0.085853 -0.134891        0
# 202000239  0.711870  0.558626 -0.500955  1.250389  1.460067  1.034898        1
# 202000238  1.514070  1.243952 -0.470685 -0.357562 -0.289155 -1.223416        1
#
# [928 rows x 7 columns]

# %%
total_sd.iloc[:,0:6]
# Out:
#                   0         1         2         3         4         5
# 201000313  0.245680  0.337317 -0.499007 -0.400686 -0.500339  0.430307
# 201000345  1.498794  1.637912 -0.517143 -0.326289 -0.389332 -1.040064
# 201000379 -1.054609 -1.026007 -0.464587 -0.422549 -0.316065  1.637366
# 201000055  0.451780  0.056210 -0.243285 -0.415909 -0.416385  0.588211
# 201000268  2.664561  3.373212  0.043373  0.280556  0.059086 -1.317275
# ...             ...       ...       ...       ...       ...       ...
# 202000249 -1.343254 -1.105444 -0.367138 -0.600827 -0.556324  1.098416
# 202000241 -1.056882 -1.006661 -0.397408 -0.564081 -0.541637  0.130995
# 202000246 -0.885937 -0.817888 -0.175806 -0.200302 -0.085853 -0.134891
# 202000239  0.711870  0.558626 -0.500955  1.250389  1.460067  1.034898
# 202000238  1.514070  1.243952 -0.470685 -0.357562 -0.289155 -1.223416
#
# [928 rows x 6 columns]

# %% [markdown]
# ## 2-4 t-SNE (K-means 결과 시각화)

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

model = TSNE(learning_rate=100)
transformed = model.fit_transform(total_sd.iloc[:,:6])

xs = transformed[:,0]
ys = transformed[:,1]
plt.scatter(xs,ys,c=kmeans.labels_)

plt.show()

#군집별로 잘 구분이 된 것을 알 수 있다.

# %% [markdown]
# ## 2-5 분석 결과

# %% [markdown]
# ### 버스정류장 정보 데이터와 군집화 결과 결합

# %%
total_sd.reset_index(inplace=True)

total_sd.rename(columns={'index':'정류장ID',0:'평일_전체_추정교통량',1:'평일_버스_추정교통량',2:'버스승하차',3:'평일유동인구',4:'주말유동인구',5:'평일_혼잡빈도강도'},inplace=True)

# %%
total_sd
# Out:
#          정류장ID  평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
# 0    201000313     0.245680     0.337317 -0.499007 -0.400686 -0.500339
# 1    201000345     1.498794     1.637912 -0.517143 -0.326289 -0.389332
# 2    201000379    -1.054609    -1.026007 -0.464587 -0.422549 -0.316065
# 3    201000055     0.451780     0.056210 -0.243285 -0.415909 -0.416385
# 4    201000268     2.664561     3.373212  0.043373  0.280556  0.059086
# ..         ...          ...          ...       ...       ...       ...
# 923  202000249    -1.343254    -1.105444 -0.367138 -0.600827 -0.556324
# 924  202000241    -1.056882    -1.006661 -0.397408 -0.564081 -0.541637
# 925  202000246    -0.885937    -0.817888 -0.175806 -0.200302 -0.085853
# 926  202000239     0.711870     0.558626 -0.500955  1.250389  1.460067
# 927  202000238     1.514070     1.243952 -0.470685 -0.357562 -0.289155
#
#      평일_혼잡빈도강도  cluster
# 0     0.430307        0
# 1    -1.040064        1
# 2     1.637366        0
# 3     0.588211        0
# 4    -1.317275        1
# ..         ...      ...
# 923   1.098416        0
# 924   0.130995        0
# 925  -0.134891        0
# 926   1.034898        1
# 927  -1.223416        1
#
# [928 rows x 8 columns]

# %%
total_sd['cluster'].value_counts()
# Out:
# 0    357
# 3    312
# 1    211
# 2     42
# 4      6
# Name: cluster, dtype: int64

# %% [markdown]
# 정류장ID 기준으로 결합

# %%
final = pd.merge(total_sd,busstop_info,on='정류장ID',how='left')
final.head()
# Out:
#        정류장ID  평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
# 0  201000313     0.245680     0.337317 -0.499007 -0.400686 -0.500339
# 1  201000345     1.498794     1.637912 -0.517143 -0.326289 -0.389332
# 2  201000379    -1.054609    -1.026007 -0.464587 -0.422549 -0.316065
# 3  201000055     0.451780     0.056210 -0.243285 -0.415909 -0.416385
# 4  201000268     2.664561     3.373212  0.043373  0.280556  0.059086
#
#    평일_혼잡빈도강도  cluster     정류장명     동        lat         lon
# 0   0.430307        0     권선구청   서둔동  37.256983  126.970983
# 1  -1.040064        1  남수원초등학교  세류2동  37.251091  127.016000
# 2   1.637366        0   신미주아파트   금곡동  37.268806  126.953845
# 3   0.588211        0   농수산물시장  권선1동  37.256755  127.029815
# 4  -1.317275        1    곡반중학교   곡선동  37.246081  127.034254

# %%
final_score = final[['평일_전체_추정교통량','평일_버스_추정교통량','버스승하차','평일유동인구','주말유동인구','평일_혼잡빈도강도','cluster']].groupby('cluster').mean()
final_score
# Out:
#          평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  평일_혼잡빈도강도
# cluster
# 0          -0.669294    -0.642743 -0.115858 -0.270457 -0.252401   0.686401
# 1           1.296556     1.342039  0.099662  0.148943  0.130400   0.174262
# 2           0.353485     0.385313  0.159998  3.420528  3.345642  -0.491510
# 3          -0.177179    -0.234552 -0.131052 -0.287593 -0.283407  -0.851368
# 4           0.966325     0.547683  9.083479  1.865527  1.749826   0.742647

# %%
final[final['cluster']==4].head()
# Out:
#          정류장ID  평일_전체_추정교통량  평일_버스_추정교통량      버스승하차    평일유동인구    주말유동인구  \
# 712  202000106     0.878046     0.465706   7.696090  3.166245  2.863910
# 767  202000208     2.212320     1.255091  12.940973  0.894966  0.784393
# 783  202000105     0.876194     0.542211   6.542626  2.719417  3.016686
# 843  202000219     0.848805     0.457205  14.540107  3.166245  2.863910
# 856  202000224     0.169661     0.040675   6.947162  0.589858  0.581414
#
#      평일_혼잡빈도강도  cluster       정류장명    동        lat         lon
# 712   0.235688        4  수원역.AK플라자  매산동  37.267365  127.000904
# 767   0.732922        4  수원역.노보텔수원  매산동  37.268112  126.999608
# 783   0.238530        4  수원역.AK플라자  매산동  37.264938  127.001484
# 843   0.271052        4  수원역.AK플라자  매산동  37.267460  127.000934
# 856   2.505742        4       매산시장  매산동  37.267314  127.003406

# %%
final[final['cluster']==2].head(20)
# Out:
#          정류장ID  평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
#
일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
# 0  201000313     0.245680     0.337317 -0.499007 -0.400686 -0.500339
# 2  201000379    -1.054609    -1.026007 -0.464587 -0.422549 -0.316065
# 3  201000055     0.451780     0.056210 -0.243285 -0.415909 -0.416385
# 5  201000337    -1.067028    -0.956830 -0.335080 -0.634683 -0.586656
# 9  201000357    -0.657960    -0.642600 -0.262387 -0.224799 -0.159349
#
#    평일_혼잡빈도강도  cluster                        정류장명     동        lat         lon
# 0   0.430307        0                        권선구청   서둔동  37.256983  126.970983
# 2   1.637366        0                      신미주아파트   금곡동  37.268806  126.953845
# 3   0.588211        0                      농수산물시장  권선1동  37.256755  127.029815
# 5   0.015551        0  경기도건설본부.경기도동물위생시험소.칠보마을7단지   금곡동  37.267677  126.941563
# 9  -0.074597        0          수원은혜교회.한양수자인파크원아파트   금곡동  37.266016  126.953978

# %%
final[final['cluster']==3].head()
# Out:
#         정류장ID  평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
# 6   200000292    -1.132330    -0.868892 -0.502685 -0.720434 -0.655638
# 7   202000089     0.003796     0.162321 -0.233509 -0.258024 -0.213783
# 8   201000358    -0.459328    -0.566387 -0.246306 -0.289158 -0.301892
# 11  201000348    -1.078225    -0.982625 -0.463137 -0.726201 -0.678058
# 12  202000090     0.267089     0.395063 -0.192654  0.254261  0.213953
#
#     평일_혼잡빈도강도  cluster                정류장명     동        lat         lon
# 6   -1.329341        3                백선교회   파장동  37.311610  126.977691
# 7   -0.904830        3                 화서역  화서2동  37.284140  126.990494
# 8   -1.734159        3  한양수자인파크원아파트.금호초등학교   금곡동  37.265969  126.952716
# 11  -1.056535        3               오목천공원    평동  37.243032  126.974516
# 12  -0.904830        3                 화서역  화서2동  37.283895  126.990107

# %%
final_score
# Out:
#          평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  평일_혼잡빈도강도
# cluster
# 0          -0.669294    -0.642743 -0.115858 -0.270457 -0.252401   0.686401
# 1           1.296556     1.342039  0.099662  0.148943  0.130400   0.174262
# 2           0.353485     0.385313  0.159998  3.420528  3.345642  -0.491510
# 3          -0.177179    -0.234552 -0.131052 -0.287593 -0.283407  -0.851368
# 4           0.966325     0.547683  9.083479  1.865527  1.749826   0.742647

# %% [markdown]
# ### 분석 결과

# %% [markdown]
# 유동인구가 많고, 번화가인 군집 순서 정하기
#
# -cluster4> cluster2 > cluster1 > cluster0 > cluster3
#
# 1. cluster4 : 교통량, 유동인구가 모두 많고 버스승하차도 많은 곳 / ex: 수원역 버스환승센터 등
# 2. cluster2 : 교통량은 적지만 버스승하차가 많고, 유동인구도 많은 곳 / ex:아주대병원 광교더샵주상복합 등
# 3. cluster1 : 교통량은 많지만 버스승하차와 유동인구 적은 곳 / ex:곡반중학교 남수원초등학교 등
# 4. cluster0 : 교통량, 버스승하차, 유동인구가 적지만 평일 혼잡빈도강도가 강한 곳/ ex:농수산물시장	화서오거리 등
# 5. cluster3 : 교통량, 버스승하차, 유동인구 모두 적은 곳 / ex:고등동사거리 구운동하이마트 등
#
# cluster 4 -> 1점
#
# cluster 2 -> 0.8점
#
# cluster 1 -> 0.6점
#
# cluster 0 -> 0.4점
#
# cluster 3 -> 0.2점

# %% [markdown]
# ## 3-1 군집별 점수 부여

# %%
final['score'] = ''

# %%
for i in range(len(final)):
    if final['cluster'][i]==0:
        final['score'][i]=0.4
    elif final['cluster'][i]==1:
        final['score'][i]=0.6
    elif final['cluster'][i]==2:
        final['score'][i]=0.8
    elif final['cluster'][i]==3:
        final['score'][i]=0.2
    elif final['cluster'][i]==4:
        final['score'][i]=1

# %%
final.head()
# Out:
#        정류장ID  평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
# 0  201000313     0.245680     0.337317 -0.499007 -0.400686 -0.500339
# 1  201000345     1.498794     1.637912 -0.517143 -0.326289 -0.389332
# 2  201000379    -1.054609    -1.026007 -0.464587 -0.422549 -0.316065
# 3  201000055     0.451780     0.056210 -0.243285 -0.415909 -0.416385
# 4  201000268     2.664561     3.373212  0.043373  0.280556  0.059086
#
#    평일_혼잡빈도강도  cluster     정류장명     동        lat         lon score
# 0   0.430307        0     권선구청   서둔동  37.256983  126.970983   0.4
# 1  -1.040064        1  남수원초등학교  세류2동  37.251091  127.016000   0.6
# 2   1.637366        0   신미주아파트   금곡동  37.268806  126.953845   0.4
# 3   0.588211        0   농수산물시장  권선1동  37.256755  127.029815   0.4
# 4  -1.317275        1    곡반중학교   곡선동  37.246081  127.034254   0.6

# %% [markdown]
# # 3. 군집 내 2차 분류

# %% [markdown]
# ### 방법: 같은 군집 내에서, 행정동 기준 인구밀도가 높은 곳일수록 더 높은 점수 부여

# %% [markdown]
# [https://stat.suwon.go.kr/stat/index.do]출처

# %%
people_density = pd.read_csv('data/인구면적.csv')
people_density.head()
# Out:
#       동   인구_계    면적
# 0   파장동  23573  8.62
# 1   율천동  43017  3.05
# 2  정자1동  29779  1.29
# 3  정자2동  30060  1.48
# 4  정자3동  42707  1.47

# %% [markdown]
# 인구밀도 feature 생성

# %%
people_density['인구밀도']= people_density['인구_계']/people_density['면적']
people_density.max()
# Out:
# 동          화서2동
# 인구_계      59913
# 면적        11.58
# 인구밀도    29052.4
# dtype: object

# %% [markdown]
# 군집화결과와 인구밀도 결합

# %%
final = pd.merge(final,people_density[['동','인구밀도']],how='left',on='동')
final
# Out:
#          정류장ID  평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
# 0    201000313     0.245680     0.337317 -0.499007 -0.400686 -0.500339
# 1    201000345     1.498794     1.637912 -0.517143 -0.326289 -0.389332
# 2    201000379    -1.054609    -1.026007 -0.464587 -0.422549 -0.316065
# 3    201000055     0.451780     0.056210 -0.243285 -0.415909 -0.416385
# 4    201000268     2.664561     3.373212  0.043373  0.280556  0.059086
# ..         ...          ...          ...       ...       ...       ...
# 923  202000249    -1.343254    -1.105444 -0.367138 -0.600827 -0.556324
# 924  202000241    -1.056882    -1.006661 -0.397408 -0.564081 -0.541637
# 925  202000246    -0.885937    -0.817888 -0.175806 -0.200302 -0.085853
# 926  202000239     0.711870     0.558626 -0.500955  1.250389  1.460067
# 927  202000238     1.514070     1.243952 -0.470685 -0.357562 -0.289155
#
#      평일_혼잡빈도강도  cluster                  정류장명     동        lat         lon  \
# 0     0.430307        0                  권선구청   서둔동  37.256983  126.970983
# 1    -1.040064        1               남수원초등학교  세류2동  37.251091  127.016000
# 2     1.637366        0                신미주아파트   금곡동  37.268806  126.953845
# 3     0.588211        0                농수산물시장  권선1동  37.256755  127.029815
# 4    -1.317275        1                 곡반중학교   곡선동  37.246081  127.034254
# ..         ...      ...                   ...   ...        ...         ...
# 923   1.098416        0                 화서오거리  화서1동  37.278865  126.999697
# 924   0.130995        0  숙지공원.화서동굿모닝힐.화서다산도서관  화서2동  37.284316  126.995823
# 925  -0.134891        0           엘지아파트.금강아파트  화서2동  37.287994  126.981714
# 926   1.034898        1              꽃뫼신동아아파트  화서2동  37.286663  126.986076
# 927  -1.223416        1                 진흥아파트  화서2동  37.289506  126.985096
#
#     score          인구밀도
# 0     0.4   7024.080882
# 1     0.6   6627.932961
# 2     0.4  11169.268293
# 3     0.4  24169.902913
# 4     0.6   6165.246637
# ..    ...           ...
# 923   0.4  28206.024096
# 924   0.4  12630.188679
# 925   0.4  12630.188679
# 926   0.6  12630.188679
# 927   0.6  12630.188679
#
# [928 rows x 14 columns]

# %% [markdown]
# 같은 군집 내에서 인구밀도가 높을수록 더 높은 점수 부여하기

# %%
final['category2_score']=''

# %%
for i in range(len(final)):
    for k in range(5):
        rank_lis = sorted(list(set(final[final['cluster']==k]['인구밀도'])), reverse=True) #한 군집내의 모든 인구밀도 내림차순 정렬
        for j in range(len(rank_lis)): #내림차순 정렬한 리스트의 인덱스 순서대로 적은 점수를 차감
            if final['인구밀도'][i] == rank_lis[j]:
                final['category2_score'][i] = round((final['score'][i]-(j/len(rank_lis))*0.2)*10,2) # 점수 만점을 10점으로 만들기

# %%
#실행결과
final
# Out:
#          정류장ID  평일_전체_추정교통량  평일_버스_추정교통량     버스승하차    평일유동인구    주말유동인구  \
# 0    201000313     0.245680     0.337317 -0.499007 -0.400686 -0.500339
# 1    201000345     1.498794     1.637912 -0.517143 -0.326289 -0.389332
# 2    201000379    -1.054609    -1.026007 -0.464587 -0.422549 -0.316065
# 3    201000055     0.451780     0.056210 -0.243285 -0.415909 -0.416385
# 4    201000268     2.664561     3.373212  0.043373  0.280556  0.059086
# ..         ...          ...          ...       ...       ...       ...
# 923  202000249    -1.343254    -1.105444 -0.367138 -0.600827 -0.556324
# 924  202000241    -1.056882    -1.006661 -0.397408 -0.564081 -0.541637
# 925  202000246    -0.885937    -0.817888 -0.175806 -0.200302 -0.085853
# 926  202000239     0.711870     0.558626 -0.500955  1.250389  1.460067
# 927  202000238     1.514070     1.243952 -0.470685 -0.357562 -0.289155
#
#      평일_혼잡빈도강도  cluster                  정류장명     동        lat         lon  \
# 0     0.430307        0                  권선구청   서둔동  37.256983  126.970983
# 1    -1.040064        1               남수원초등학교  세류2동  37.251091  127.016000
# 2     1.637366        0                신미주아파트   금곡동  37.268806  126.953845
# 3     0.588211        0                농수산물시장  권선1동  37.256755  127.029815
# 4    -1.317275        1                 곡반중학교   곡선동  37.246081  127.034254
# ..         ...      ...                   ...   ...        ...         ...
# 923   1.098416        0                 화서오거리  화서1동  37.278865  126.999697
# 924   0.130995        0  숙지공원.화서동굿모닝힐.화서다산도서관  화서2동  37.284316  126.995823
# 925  -0.134891        0           엘지아파트.금강아파트  화서2동  37.287994  126.981714
# 926   1.034898        1              꽃뫼신동아아파트  화서2동  37.286663  126.986076
# 927  -1.223416        1                 진흥아파트  화서2동  37.289506  126.985096
#
#     score          인구밀도 category2_score
# 0     0.4   7024.080882            2.42
# 1     0.6   6627.932961            4.26
# 2     0.4  11169.268293            2.58
# 3     0.4  24169.902913            3.79
# 4     0.6   6165.246637            4.21
# ..    ...           ...             ...
# 923   0.4  28206.024096            3.89
# 924   0.4  12630.188679            2.79
# 925   0.4  12630.188679            2.79
# 926   0.6  12630.188679            4.79
# 927   0.6  12630.188679            4.79
#
# [928 rows x 15 columns]

# %% [markdown]
# 필요한 변수만 저장

# %%
category2 = final[['정류장ID','정류장명','동','lat','lon','category2_score']]
category2
# Out:
#          정류장ID                  정류장명     동        lat         lon  \
# 0    201000313                  권선구청   서둔동  37.256983  126.970983
# 1    201000345               남수원초등학교  세류2동  37.251091  127.016000
# 2    201000379                신미주아파트   금곡동  37.268806  126.953845
# 3    201000055                농수산물시장  권선1동  37.256755  127.029815
# 4    201000268                 곡반중학교   곡선동  37.246081  127.034254
# ..         ...                   ...   ...        ...         ...
# 923  202000249                 화서오거리  화서1동  37.278865  126.999697
# 924  202000241  숙지공원.화서동굿모닝힐.화서다산도서관  화서2동  37.284316  126.995823
# 925  202000246           엘지아파트.금강아파트  화서2동  37.287994  126.981714
# 926  202000239              꽃뫼신동아아파트  화서2동  37.286663  126.986076
# 927  202000238                 진흥아파트  화서2동  37.289506  126.985096
#
#     category2_score
# 0              2.42
# 1              4.26
# 2              2.58
# 3              3.79
# 4              4.21
# ..              ...
# 923            3.89
# 924            2.79
# 925            2.79
# 926            4.79
# 927            4.79
#
# [928 rows x 6 columns]

# %%
category2.sort_values(by=["category2_score"], ascending=[False]).head(30)
# Out:
#          정류장ID                     정류장명       동        lat         lon  \
# 783  202000105                수원역.AK플라자     매산동  37.264938  127.001484
# 712  202000106                수원역.AK플라자     매산동  37.267365  127.000904
# 767  202000208                수원역.노보텔수원     매산동  37.268112  126.999608
# 870  202000225                 수원역.역전시장     매산동  37.265116  127.001845
# 843  202000219                수원역.AK플라자     매산동  37.267460  127.000934
# 856  202000224                     매산시장     매산동  37.267314  127.003406
# 801  202000120                 수원역.헌혈의집     매산동  37.266401  127.001585
# 198  201000197                  수원버스터미널    권선2동  37.249796  127.019716
# 123  203000152  영통아이파크캐슬1단지.래미안영통마크원2단지  망포1.2동  37.245039  127.046286
# 587  203000153  래미안영통마크원2단지.영통아이파크캐슬1단지  망포1.2동  37.245427  127.045991
# 246  203000076          청명역6번출구.황골주공1단지    영통1동  37.260512  127.079566
# 516  203000121              청명역1번출구.청명산    영통1동  37.260481  127.080218
# 651  203000075                  청명역4번출구    영통1동  37.258279  127.077445
# 515  203000122                  청명역3번출구    영통1동  37.258802  127.078635
# 304  202000032                   효성초등학교    우만2동  37.282067  127.039590
# 461  203000184         삼성DigitalCity홍보관    매탄3동  37.258555  127.057438
# 33   203000185         삼성DigitalCity홍보관    매탄3동  37.258619  127.057094
# 534  203000002        동수원우체국.인계래미안노블클래스    매탄1동  37.267093  127.033339
# 551  202000011                   중소기업은행     인계동  37.266237  127.033395
# 569  203000071          광교호수공원입구.원천교사거리     원천동  37.270955  127.059640
# 45   203000188                 광교더샵주상복합     원천동  37.270451  127.061896
# 473  203000174               원천레이크파크아파트     원천동  37.269424  127.062484
# 474  203000171                    아주대병원     원천동  37.278352  127.046900
# 659  201000591            수원역환승센터(5승강장)     서둔동  37.265261  126.998712
# 660  201000588            수원역환승센터(2승강장)     서둔동  37.265404  126.999280
# 690  201000589            수원역환승센터(3승강장)     서둔동  37.265253  126.999154
# 699  201000592            수원역환승센터(6승강장)     서둔동  37.265428  126.998503
# 872  201000587            수원역환승센터(1승강장)     서둔동  37.265649  126.999135
# 626  201000218                  탑동우방아파트     서둔동  37.268743  126.971602
# 714  201000597           수원역환승센터(11승강장)     서둔동  37.265962  126.998833
#
#     category2_score
# 783              10
# 712              10
# 767              10
# 870              10
# 843              10
# 856              10
# 801               8
# 198            7.84
# 123            7.74
# 587            7.74
# 246            7.63
# 516            7.63
# 651            7.63
# 515            7.63
# 304            7.53
# 461            7.16
# 33             7.16
# 534            7.05
# 551            6.89
# 569            6.74
# 45             6.74
# 473            6.74
# 474            6.74
# 659            6.42
# 660            6.42
# 690            6.42
# 699            6.42
# 872            6.42
# 626            6.42
# 714            6.42

# %% [markdown]
# 결과 저장하기

# %%
category2.to_csv('data/category2.csv',index=False)

# %%
category2_with_cluster = final[['정류장ID','정류장명','동','lat','lon','category2_score','cluster']]
category2_with_cluster
# Out:
#          정류장ID                  정류장명     동        lat         lon  \
# 0    201000313                  권선구청   서둔동  37.256983  126.970983
# 1    201000345               남수원초등학교  세류2동  37.251091  127.016000
# 2    201000379                신미주아파트   금곡동  37.268806  126.953845
# 3    201000055                농수산물시장  권선1동  37.256755  127.029815
# 4    201000268                 곡반중학교   곡선동  37.246081  127.034254
# ..         ...                   ...   ...        ...         ...
# 923  202000249                 화서오거리  화서1동  37.278865  126.999697
# 924  202000241  숙지공원.화서동굿모닝힐.화서다산도서관  화서2동  37.284316  126.995823
# 925  202000246           엘지아파트.금강아파트  화서2동  37.287994  126.981714
# 926  202000239              꽃뫼신동아아파트  화서2동  37.286663  126.986076
# 927  202000238                 진흥아파트  화서2동  37.289506  126.985096
#
#     category2_score  cluster
# 0              2.42        0
# 1              4.26        1
# 2              2.58        0
# 3              3.79        0
# 4              4.21        1
# ..              ...      ...
# 923            3.89        0
# 924            2.79        0
# 925            2.79        0
# 926            4.79        1
# 927            4.79        1
#
# [928 rows x 7 columns]

# %% [markdown]
# 군집과 점수가 같이나와있는 데이터 저장

# %%
category2_with_cluster.to_csv('data/category2_wiith_cluster.csv',index=False)
